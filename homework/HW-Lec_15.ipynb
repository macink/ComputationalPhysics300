# %%
# %matplotlib notebook
#code to solve minimum of 2D function with Monte Carlo method

#First let's check out the plot
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#set up range
x_min, x_max = -2,2
y_min, y_max = -2,2

#function to plot and minimize
def f(x,y):
    return x**2/2 + y**2/3 - x*y/4

#arrays to hold grid coordinates
nx = np.linspace(x_min, x_max, 100)
ny = np.linspace(y_min, y_max, 100)

#array for values from function
x,y = np.meshgrid(nx,ny)

z = f(x,y)

#set up plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(x,y,z, cmap='summer', alpha=0.8)
cset = ax.contour(x,y,z, zdir='z', offset=0)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('$f(x,y)$')

plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(block=None)>

# %%
#looks like the range of -2,2 is good.

from random import random
from scipy.optimize import minimize

def f(x,y):
    return x**2/2 + y**2/3 - x*y/4

def MC_Min_Method(f, N=1000):
    '''
    Function find minimum value of function on given interval
    using the Monte Carlo method of random numbers on the function
    and then take the minimum of these values
    '''
    x_min, x_max = -2,2
    y_min, y_max = -2,2
    
    x0 = x_min + np.random.random()*(x_max-x_min)
    y0 = y_min + np.random.random()*(y_max-y_min)
    
    for i in range(N):
        '''This is to get N points on curve of function'''
        x = random()
        y = random()
        if f(x,y)<f(x0,y0):
            now = f(x,y)
    return now

MC_Min_Method(f)
# Out:
# 0.2659787031203046
